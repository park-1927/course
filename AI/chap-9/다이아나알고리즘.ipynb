# %% [markdown]
# #[계층적 응집 클러스터링](https://)
# - 하향식 접근법 또는 계층적 응집 클러스터링(HAC)이라고도 함
# - 플랫 클러스터링에서 반환된 비구조화된 클러스터 집합보다 더 많은 정보를 제공하는 구조
# - 이 클러스터링 알고리즘은 클러스터 수를 미리 지정할 필요가 없음
# - [하향식 알고리즘은 각 데이터를 처음에 싱글톤 클러스터로 처리한 다음 모든 클러스터가 모든 데이터를 포함하는 단일 클러스터로 병합될 때까지 클러스터 쌍을 연속적으로 응집함](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# randomly chosen dataset
X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])

# here we need to mention the number of clusters
# otherwise the result will be a single cluster
# containing all the data
clustering = AgglomerativeClustering(n_clusters=2).fit(X)

# print the class labels
print(clustering.labels_)
# Out:
# [1 1 1 0 0 0]

# %% [markdown]
# ---

# %% [markdown]
# #[계층적 분할 클러스터링](https://)
# - 하향식 접근법
# - 클러스터 수를 미리 지정할 필요가 없음
# - 하향식 클러스터링은 전체 데이터를 포함하는 클러스터를 분할하는 방법이 필요하며 개별 데이터가 싱글톤 클러스터로 분할될 때까지 클러스터를 재귀적으로 분할하여 진행함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[DIANA(DIvisive ANAlysis)](https://)
# - Top-down 방식의 hierarchical clustering method
# - Splus 같이 statistical analysis packages에 구현되어있음
# - 개념적으로는 AGNES(bottom-up)과 반대이지만 순서적으로 완전히 역순은 아님
# - [각 object를 하나의 cluster로 만들기 위해 과정을 반복해나감](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[덴드로그램 군집분석](https://)
# - 데이터를 [군집으로 나누고 그 군집들의 관계를 분석하는 군집분석의 결과를 트리 형태의 덴드로그램으로 시각화한 것](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# randomly chosen dataset
X = np.array([[1, 2], [1, 4], [1, 0],
              [4, 2], [4, 4], [4, 0]])

# Perform hierarchical clustering
Z = linkage(X, 'ward')

# Plot dendrogram
dendrogram(Z)

plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Data point')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #<<<참조자료 사이트>>>
# 1.[DIANA(DIvisive ANAlysis)](https://gofo-coding.tistory.com/entry/Hierarchical-Clustering-DIANA-Divisive-Analysis)
# 2.[Hierarchical Clustering in Machine Learning](https://www.geeksforgeeks.org/hierarchical-clustering/)
# 3.[군집분석(Clustering)(2) - Hierarchical clustering(계층적 군집분석) 이론](https://m.blog.naver.com/winddori2002/221881570066)
# 4.[클러스터링 분석 - ③ 계층적 군집화와 덴드로그램](https://datananalysis.tistory.com/130)
