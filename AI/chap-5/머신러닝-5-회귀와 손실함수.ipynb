# %% [markdown]
# #[회귀와 손실 함수](https://)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[회귀 분석/독립변수/종속변수](https://colab.research.google.com/drive/1ZcGWqzIm_zatf-2F5Us6vNI6kcpelsCJ?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[파라미터와 하이퍼파라미터](https://colab.research.google.com/drive/1r5qaGf27oQpOzfw21q3JUDPIYAV8uxu3?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[잔차/오차/표준오차](https://colab.research.google.com/drive/1uqWn3eemNQ__JbGrvcPQMUiyVdzqbHJ-?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[함수의 정의 및 유형](https://colab.research.google.com/drive/14J8ni1j6B2HNUNc1wtxu4IJdEYNDEyUK?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[결정계수 (R -Squared, R2)](https://colab.research.google.com/drive/1IAIBhIbQLXSBZbm8vkfs0vqEhO7EcIaO?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[회귀모델-선형회귀](https://colab.research.google.com/drive/1zzqu6HWisOOChmc5BUGqyUsfgC9AHtr7?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[회귀모델-다중/다항회귀](https://colab.research.google.com/drive/1UjYTb_M9a_OhsTS6SXZT1Szde6ZiVYGx?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[분류에서 손실함수](https://colab.research.google.com/drive/1KhuLB-GXMK2tEFyhtrCKfRSyjiVdkrgv?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[규제(Regularization), 라쏘 회귀(Lasso Regression)와 릿지 회귀(Ridge Regression)](https://colab.research.google.com/drive/1EloYzbyGHZeCAkzNT8-ldmVsPd9wh7G9?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[로지스틱 회귀(Logistic Regression)](https://colab.research.google.com/drive/1wA4HKGwkqIgRo6cv2Cn3ieN-cG16KVVW?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #<<<참조자료 사이트>>>
# 1.[회귀분석이란 무엇인가?](https://brunch.co.kr/@minnation/3388)
# 2.[독립 변수란? 종속 변수란?](https://panython.tistory.com/49)
# 3.[결정계수 R-Squared](https://modulabs.co.kr/blog/r-squared)
# 4.[단순 선형 회귀(Simple Linear Regression)](https://yhyun225.tistory.com/9)
# 5.[다중 선형 회귀 (Multi Linear Regression)](https://yhyun225.tistory.com/10)
# 6.[다중 선형 회귀 (Multi Variable Linear Regression)](https://keykat7.blogspot.com/2019/10/ai-day4-multi-variable-linear-regression.html)
# 7.[딥러닝 개발자라면 꼭 알아야 할 손실 함수 의 개념과 종류](https://modulabs.co.kr/blog/machine_learning_loss_function)
# 8.[딥러닝 개발자라면 꼭 알아야 할 손실 함수 의 개념과 종류](https://modulabs.co.kr/blog/machine_learning_loss_function)
# 9.[로지스틱 회귀](https://ratsgo.github.io/machine%20learning/2017/04/02/logistic/)
# 10.[다항회귀(Polynomial Regression)란?](https://softtone-someday.tistory.com/23)
# 11.[다중선형회귀그래프 그리기 (+sklearn, mpl_toolkits)](https://lovelydiary.tistory.com/346)

# %% [markdown]
# ---

# %% [markdown]
# 1.[인공지능 특강 5강 회귀와 손실함수](https://www.youtube.com/watch?v=OcpUsAHNFgU&loop=0)
# 2.[[인공지능을 위한 머신러닝 101] 선형회귀란 무엇인가?](https://www.youtube.com/watch?v=06EqCxjrmX0&loop=0)
# 3.[알기 쉬운 딥러닝 3강 : 손실함수 (loss function) 로 컴퓨터에게 오차를 알려줘야함](https://www.youtube.com/watch?v=_JOjr8tVLSU&t=293s)
# 4.[19. 오차와 손실함수(loss function)](https://www.youtube.com/watch?v=z08BEiw5_WA)
