# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # 활성화 함수
# - Sigmoid나 tanh와 같은 활성화 함수는 입력 값이 매우 크거나 작을 때 출력의 변화가 매우 작다. 예를 들어 Sigmoid의 도함수는 아래와 같다.
# - 여기서 σ(x)가 0 또는 1에 가까워지면 도함수가 0에 가까워진다. 이러한 활성화 함수들은 입력 값이 크거나 작을 때 기울기를 거의 0으로 만들기 때문에, 역전파 동안 기울기가 점점 더 작아진다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[기울기 소실(Gradient Vanishing)와 기울기 폭주(Gradient Exploding)](https://colab.research.google.com/drive/1UTGfuC2x4krwNB4DIeUvgPndMycoH6D4?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[기울기 소실(Gradient Vanishing)과 폭주(Exploding)를 완화하는 방법](https://colab.research.google.com/drive/1qtT5TSgHNsfk9xUy04nbUY6b0P61oDpY?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[순전파/역전파](https://colab.research.google.com/drive/1DAYYCiLMdSbvzgy-NOSMoNMkmEvDhp5B?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[배치정규화](https://colab.research.google.com/drive/1HRPEo5QDBVDwtROdQN3vIYzbbY5Iq_Td?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[데이터 증강(Data Augmentation)이해](https://colab.research.google.com/drive/12aHRB15GNmu9MLyCTKym2BwZo_XjyoAC?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #[드롭아웃](https://colab.research.google.com/drive/1BtDqD9tmu6e3QMTVI2FkfjZLV6k-X4i0?usp=drive_link)

# %% [markdown]
# ---

# %% [markdown]
# #<<<참조자료 사이트>>>
# 1.[기울기 소실(Gradient Vanishing)과 폭주(Exploding) 해결 방법 | ReLU 함수와 Leaky ReLU 함수, 그래디언트 클리핑(Gradient Clipping), 배치 정규화(Batch Normalization)](https://iambeginnerdeveloper.tistory.com/188)
# 2.[Vanishing Gradient와 ReLU 함수](https://minkithub.github.io/2020/05/27/everydeeplearning7/)
# 3.[Neural Network로 XOR 분류 해결하기](https://minkithub.github.io/2020/05/23/everydeeplearning6/)

# %% [markdown]
# ---

# %% [markdown]
# 1.[인공신경망에서의 기울기 소실 문제](https://www.youtube.com/watch?v=BwkquF9QQLU)
# 2.[인공지능 특강 17강. 딥러닝 학습에서 마주하는 문제들](https://www.youtube.com/watch?v=eFXGuLCnBYo&list=PLWtr7MRpQi5ATPYo3xN21Bwwd_Ut4rY0d&index=17)

# %% [markdown]
# ---
