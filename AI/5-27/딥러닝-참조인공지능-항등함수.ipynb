# %% [markdown]
# #[항등함수(identity function)](https://)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 항등함수는 입력을 그대로 출력하는 함수
# >- 입력과 출력이 항상 같다는 뜻의 항등
# >- 신경망에서 항등함수를 사용하게 되면, 입력 신호와 출력신호가 같음
# >- 출력층에서 사용하는 활성화 함수로 항등함수는 회귀에서 주로 사용, 분류에서는  소프트맥스 함수를 이용

# %% [markdown]
# ---

# %%
def identity_function(x):
	return x

identity_function(5)

# %% [markdown]
# ---

# %% [markdown]
# #<<<참조자료 사이트>>>
# 1.[항등함수와 Softmax 함수](https://welcome-to-dewy-world.tistory.com/85)
# 2.[항등 함수와 소프트맥스 함수](https://datapilots.tistory.com/110)
