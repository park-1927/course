# %% [markdown]
# #[아두이노(arduino)](https://)

# %% [markdown]
# ---

# %% [markdown]
# #[마이크로컨트롤러(microcontroller 또는 MCU(microcontroller unit))란 무엇인가? & 일반적인 컴퓨터와 다른 점은 무엇일까요?](https://)
# - [컴퓨터는 여러가지 부품으로 구성](https://)
# >- CPU(중앙처리장치, 계산과 제어를 담당), RAM(데이터저장 메모리), ROM(프로그램저장 메모리), 입출력 포트(USB포트, 시리얼포트, 패러렐 포트...) 등으로 구성
# >- 이것들은 각각의 반도체 소자로서 PCB에 조립되어 한나의 메인보드로 만들어짐
# - [마이크로컨트롤러는 각각의 반도체들을 하나의 IC에 통합](https://)
# >- [원칩 디바이스로 만들어지며](https://)
# >- 추가로 아날로그 컨버터(ADC). 디지털 컨버터(DAC)과 같은 추가적인 기능도 포함하고 있음
# >- 복잡한 계산을 빠른 속도로 하는 목적으로 만들어진 것이 아니며, 냉장고, 에어컨, 세탁기처럼 비교적 단순한 제어를 하는 곳에 사용되며 가격도 저렴함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[아두이노 소개](https://)
# - [오픈 소스를 기반으로 한 단일 보드 마이크로컨트롤러로 완성된 보드(상품)와 관련 개발 도구(IDE) 및 환경](https://)
# - 물리적인 환경을 감지하고 제어하는 툴로서 만들어졌으며 마이크로컨트롤러를 기본으로 오픈 하드웨어어 프로젝트로 사작되었음
# >- 이 프로젝트는 [아두이노 하드웨어와 프로그램을 개발하기 위한 아두이노 IDE 소프트웨어로 구성](https://)
# - 아두이노 우노 R3 보드에 사용되는 ATMEL사의[ ATMEGA328P 마이크로 컨트롤러](https://)
# >- [칩하나에 CPU, ROM, RAM, ADC, 디지털IO, 아날로그IO 등을 모두 내장하고 있음](https://)
# >- 또한 8비트의 프로세서로서 최대 20MHz속도로 동작하며 프로그램메모리는 32KB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[아두이노 보드](https://)
# - 방대한 종류의 센서, 스위치류의 신호를 받아 모터, LCD, 스피커, LED 등의 물리적인 장치들을 제어

# %% [markdown]
# ---

# %% [markdown]
# #[아두이노 IDE소프트웨어](https://)
# - 오픈소스로서 무료로 사용할 수 있으며, 이 소프트웨어를 통해 제어프로그램을 제작하여 아두이노 보드로 업로드하므로서 아두이노 보드로 원하는 작업을 할 수 있음

# %% [markdown]
# ---

# %% [markdown]
# #[아두이노 보드를 사용하면 기존에 마이크로컨트롤러를 통한 개발에 비해 프로그램 개발이 매우 단순하고 쉬워서 전문기술자가 아니어도 사용이 가능하다는 장점이 있음](https://)
# - [저렴한 가격](https://) - 아두이노 보드는 다른 플랫폼의 보드에 비해 저렴한 가격에 구매가 가능
# - [다양한 OS 지원](https://) - 아두이노 IDE는 윈도우 환경 뿐만 아니라 맥OS, 리눅스에서도 사용이 가능
# - [쉬운 개발 환경](https://) - 초보자도 쉽게 배울 수 있으며 각종 라이브러리는 물론 방대한 관련 소스를 구할 수 있어 개발이 쉬움
# - [오픈소스/오픈하드웨어 - 아두이노 보드 및 아두이노 IDE는 모두 오픈 프로젝드로 시작되어 자신만의 아두이노 보드 및 소프트웨어 환경을 구축할 수 있음](https://)

# %% [markdown]
# ---

# %% [markdown]
# #[아두이노 우노보드](https://)
# - 아두이노 보드중에서도 [가장 대중적이고 대표적인 보드](https://)
# - 하드웨어 구성
# >- 디지털 IO : 디지털 입출력포트 0-13
# >- 아날로그IO : 아날로그 입출력포트 0-5
# >- ICSP 다운로드포트
# >- 시리얼 통신용 RX/TX
# >- 전원 입력 방법: USB인터페이스, DC 7-12V 아답터, Vin 외부전압입력(DC 7-12V)
# >- 전압 출력 : 3.3V & 5V
# >- [마이크로컨트롤러 : ATMEGA328P](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아두이노 우노보드의 특별한 하드웨어 핀
# >- [Vin핀](https://)
# >>- 외부 전원 입력을 받기 위한 핀
# >>- [만약 USB포트를 전원을 공급받지 않는 경우에는 Vin핀으로 외부 전원(또는 배터리; DC7-12V)을 공급받을 수 있음](https://)
# >- [AREF핀](https://)
# >>- 아날로그 입력 레퍼런스 전압 핀
# >>- 아날로그 입력의 최대치를 설정하기 위해 사용
# >>- 0-5V 사이의 전압으로만 사용하여야 하며, 프로그램에서는 analogReference() 명령어로 불러서 사용
# >- [ICSP핀](https://)
# >>- [일반적으로 ISP(In-System Programmer)라고 함](https://)
# >>- 이 핀을 통해 마이크로컨트롤러(여기서는 ATMEGA328P)를 직접 프로그램할 수 있음
# >>- [아두이노 보드에 펌웨어를 구울 때 사용](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[아두이노 통합개발환경(Arduino IDE) = '아두이노 소프트웨어'](https://)
# - [프로세싱을 기반으로 개발된 편집기, 컴파일러, 업로더 등이 합쳐진 소프트웨어 환경](https://)
# - 기타 개발에 필요한 각종 옵션 및 라이브러리 관리를 할 수 있음
# - 아두이노 프로그램 실행 시, 컴퓨터와 시리얼 통신을 할 수 있는 가상 시리얼모니터를 제공
# - 보통 USB을 통해 업로드를 하므로 아두이노 보드는 USB를 UART 통신으로 바꾸는 방법이 제공되며, MCU가 실행할 때는 이 UART 통신을 이용하여 필요한 통신을 할 수 있음
# - [아두이노 IDE로 작성된 프로그램을 '스케치(Sketch)'라고 부름](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[ARDUINO SOFTWARE](https://)
# - [Arduino IDE 2.3.4](https://www.arduino.cc/en/software)
# - [OldSoftwareReleases-ARDUINO 1.8.18](https://www.arduino.cc/en/software/OldSoftwareReleases)

# %% [markdown]
# ---

# %% [markdown]
# #[Download and install Arduino IDE](https://support.arduino.cc/hc/en-us/articles/360019833020-Download-and-install-Arduino-IDE)
# - [아두이노 스케치 설치하기_1](https://ssam.teacherville.co.kr/ssam/contents/21230.edu)
# - [아두이노 스케치 설치하기_2](https://kwanulee.github.io/iot/docs/starting_arduino/install_arduino_ide.html)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[스케치 예시 코드(LED 켜고 끄기)](https://)
# - #아두이노 스케치는 C++와 비슷한 문법을 가지고 있음

# %%
#아두이노 스케치는 C++와 비슷한 문법을 가지고 있음

//전역변수 설정 부분
#define LED_PIN 13
int time = 1000;

//리셋버튼을 누르거나 전원을 넣은 후 딱 한번만 실행되는 셋업 함수
void setup() {
    pinMode(LED_PIN, OUTPUT);
}

//계속 실행되는 함수
void loop() {
  digitalWrite(LED_PIN, HIGH);  // LED를 켬
  delay(time);                  // 1초동안 기다림
  digitalWrite(LED_PIN, LOW);   // LED를 끔
  delay(time);                  // 1초동안 기다림
}

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #[tinkercad](https://www.tinkercad.com/dashboard/designs/circuits)

# %% [markdown]
# ---

# %% [markdown]
# #[아두이노기반 드론](https://)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# #<<<참조자료 사이트>>>
# 1.[아두이노 프로그램 코드(스케치) 작성 방법](https://sangmin0523memo.tistory.com/11)

# %% [markdown]
# ---
